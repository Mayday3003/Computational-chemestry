# %% [markdown]
# # Ag₂S₂O₇ mp-1192057

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# Dentro de este sistema cristalino podemos observar  como el espacio es rellenado por pirámides, pero, también por huecos octaedrales, las pirámides están en los átomos de Azufre, y estos conectan con los átomos de Óxigeno en los vértices, por otro lado las formas octaedrales están formadas por, Ag y estas conectan todos sus vértices con los átomos de Óxigeno de la misma forma que el Azufre, solo formando diferentes tipos de huecos

# %% [markdown]
# # Ag₂GeS₃  mp-9900

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# Dentro de este sistema cristalino podemos observar  como el espacio es rellenado por pirámides, tanto los átomos de G y Ag estando en el centro, al unirse al S se pueden observar pirámides bien definidas, cada una con 4 caras y con Azufre en sus vértices
